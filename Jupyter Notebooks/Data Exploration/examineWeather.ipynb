# %%
import pandas as pd

weather = pd.read_csv('E:/University/Fall 2019/COMP 4480 - Directed Studies/Final Data/Weather/Vancouver_Airport_Weather_Hourly.csv')

# %%
weather.shape
# Out:
# (146141, 6)

# %%
weather
# Out:
#                Date/Time  Temp (°C)  Rel Hum (%)  Visibility (km)  \
# 0       2003-01-01 00:00        5.8         81.0             24.1
# 1       2003-01-01 01:00        6.2         78.0             24.1
# 2       2003-01-01 02:00        6.6         76.0             24.1
# 3       2003-01-01 03:00        5.5         88.0             24.1
# 4       2003-01-01 04:00        5.5         88.0             24.1
# ...                  ...        ...          ...              ...
# 146136  2019-08-31 19:00       18.0         84.0             48.3
# 146137  2019-08-31 20:00       18.2         84.0             48.3
# 146138  2019-08-31 21:00       18.0         85.0             32.2
# 146139  2019-08-31 22:00       19.3         75.0             32.2
# 146140  2019-08-31 23:00       19.0         81.0             32.2
#
#         Stn Press (kPa)        Weather
# 0                101.70         Cloudy
# 1                101.73         Cloudy
# 2                101.71         Cloudy
# ...
