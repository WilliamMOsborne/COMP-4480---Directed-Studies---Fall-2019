# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import sklearn

original_blocks = pd.read_csv('E:/Vancouver Crime Final/Synthetic Data/hundred_block_spread.csv')

original_blocks
# Out:
#                       hundred_block  count  utm_x_min  utm_x_max  x-spread  \
# 0                   0K E CORDOVA ST      1  493672.91  493672.91       0.0
# 1               1000MARINASIDE CRES      1  491604.46  491604.46       0.0
# 2                      100KEEFER ST      1  492579.94  492579.94       0.0
# 3           100O BLOCK KINGSWAY AVE      1  492769.00  492769.00       0.0
# 4                  100O E PENDER ST      1  492571.01  492571.01       0.0
# ...                             ...    ...        ...        ...       ...
# 21981         YUKON ST / W 59TH AVE      1  491597.00  491597.00       0.0
# 21982          YUKON ST / W 5TH AVE      5  491797.00  491797.00       0.0
# 21983          YUKON ST / W 6TH AVE      1  491794.00  491794.00       0.0
# 21984     YUKON ST / W BROADWAY AVE     11  491786.00  491786.00       0.0
# 21985  YUKON ST / W KING EDWARD AVE      5  491786.00  491835.00      49.0
#
#         utm_y_min   utm_y_max  y-spread
# ...

# %%
blocks = original_blocks['hundred_block'].values.tolist()

# %%
len(blocks)
# Out:
# 21986

# %%
blocks
# Out:
# ['0K E CORDOVA ST',
#  '1000MARINASIDE CRES',
#  '100KEEFER ST',
#  '100O BLOCK KINGSWAY AVE',
#  '100O E PENDER ST',
#  '1046A ODLUM DR',
#  '1095B SITKA SQ',
#  '10O BLOCK W HASTINGS ST',
#  '10O E 11TH AVE',
#  '10O E CORDOVA ST',
#  '10O W PENDER ST',
#  '10XX ALBERNI ST',
#  '10XX BALFOUR AVE',
#  '10XX BARCLAY ST',
#  '10XX BEACH AV',
#  '10XX BEACH AVE',
#  '10XX BEATTY WALK',
#  '10XX BIDWELL ST',
#  '10XX BLOCK ALBERNI ST',
#  '10XX BLOCK BARCLAY ST',
#  '10XX BLOCK BEACH AVE',
#  '10XX BLOCK BOUNDARY RD',
#  '10XX BLOCK BURNABY ST',
#  '10XX BLOCK BURRARD ST',
#  '10XX BLOCK BUTE ST',
#  '10XX BLOCK CAMBIE ST',
#  '10XX BLOCK CLARK DR',
#  '10XX BLOCK COMMERCIAL DR',
#  '10XX BLOCK COMOX ST',
#  '10XX BLOCK DAVIE ST',
#  '10XX BLOCK DENMAN ST',
#  '10XX BLOCK DEVONSHIRE CRES',
#  '10XX BLOCK DUNSMUIR ST',
#  '10XX BLOCK E 10TH AVE',
#  '10XX BLOCK E 12TH AVE',
#  '10XX BLOCK E 33RD AVE',
#  '10XX BLOCK E 41ST AVE',
#  '10XX BLOCK E 49TH AVE',
#  '10XX BLOCK E 52ND AVE',
# ...

# %%
import random


random_blocks = []


for x in range(500000):
    random_blocks.append(blocks[random.randint(0, 21985)])
    
len(random_blocks)
# Out:
# 500000

# %%
from pandas import DataFrame

random_df = DataFrame(random_blocks,columns=['hundred_block'])

random_df
# Out:
#                   hundred_block
# 0                 39XX PUGET DR
# 1          CROWE ST / W 1ST AVE
# 2                42XX NOOTKA ST
# 3       GRAVELEY ST / COTTON DR
# 4          4XX BLOCK E 41ST AVE
# ...                         ...
# 499995         40XX BOUNDARY RD
# 499996          37XX W 31ST AVE
# 499997            42XX YUKON ST
# 499998          19XX W 39TH AVE
# 499999   E 35TH AVE / KNIGHT ST
#
# [500000 rows x 1 columns]

# %%
random_df.to_csv('E:/Vancouver Crime Final/Synthetic Data/random_blocks.csv')
